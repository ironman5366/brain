# %%
import sys
from pathlib import Path 

sys.path.append(  
    str(Path.cwd().parent)
)

# %%
data_path = Path(
    "/kreka/research/willy/side/brain_datasets/alljoined-2025-12-13/alljoined-2025-12-13-train.safetensors"
)

# %%
import importlib 
import data.dataset 
importlib.reload(data.dataset)
# Out:
# <module 'data.dataset' from '/kreka/research/willy/side/brain/data/dataset.py'>

# %%
ds = data.dataset.EEGDataset( 
    samples_path=data_path
)
# Out:
# Loading samples from /kreka/research/willy/side/brain_datasets/alljoined-2025-12-13/alljoined-2025-12-13-train.safetensors...

# %%
sample = ds[0]
sample, sample.shape
# Out:
# (tensor([[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.2108, 0.0878, 0.0142,  ..., 0.2366, 0.3243, 0.4402],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          ...,
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.8981, 0.6632, 0.5431,  ..., 0.4177, 0.5113, 0.7621]]),
#  torch.Size([354, 256]))

# %%
from torch.utils.data import DataLoader
dl = DataLoader(ds, batch_size=8, num_workers=8)

# %%
from tqdm import tqdm

for x in tqdm(dl):
    pass
# Out:
# 100%|██████████| 52304/52304 [00:46<00:00, 1136.30it/s]
