# %%
import sys
from pathlib import Path 

sys.path.append(  
    str(Path.cwd().parent)
)

# %%
data_path = Path(
    # "/kreka/research/willy/side/brain_datasets/alljoined-2025-12-13/alljoined-2025-12-13-train.safetensors"
    "/kreka/research/willy/side/brain_datasets/alljoined-epochs-2025-12-21/alljoined-epochs-2025-12-21-val.safetensors"
)

# %%
import importlib 
import data.dataset 
importlib.reload(data.dataset)
# Out:
# <module 'data.dataset' from '/kreka/research/willy/side/brain/data/dataset.py'>

# %%
ds = data.dataset.EEGDataset( 
    samples_path=data_path
)
# Out:
# Loading samples from /kreka/research/willy/side/brain_datasets/alljoined-epochs-2025-12-21/alljoined-epochs-2025-12-21-val.safetensors...

# %%
sample = ds[0]
sample, sample.shape
# Out:
# (tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#          [-0.2036, -0.0632,  0.0419,  ..., -0.9380, -0.9230, -0.9616],
#          [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#          ...,
#          [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#          [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#          [-0.0589,  0.1222,  0.2221,  ..., -0.9585, -0.9423, -0.9099]]),
#  torch.Size([354, 308]))

# %%
from torch.utils.data import DataLoader
dl = DataLoader(ds, batch_size=8, num_workers=8)

# %%
from tqdm import tqdm

for x in tqdm(dl):
    pass
# Out:
# 100%|██████████| 21394/21394 [00:20<00:00, 1055.43it/s]

# %%
meta_file = data_path.parent / "alljoined-epochs-2025-12-21-val-metadata.parquet"

# %%
import polars as pl
df = pl.read_parquet(meta_file)

# %%
df
# Out:
# shape: (171_146, 14)
# ┌───────────┬──────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ epoch_idx ┆ image_id ┆ partition ┆ onset     ┆ … ┆ category_ ┆ super_cat ┆ category_ ┆ super_cat │
# │ ---       ┆ ---      ┆ ---       ┆ ---       ┆   ┆ name      ┆ egory     ┆ num       ┆ egory_id  │
# │ i64       ┆ i64      ┆ str       ┆ f64       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │           ┆          ┆           ┆           ┆   ┆ str       ┆ str       ┆ i64       ┆ i64       │
# ╞═══════════╪══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 0         ┆ 8242     ┆ stim_trai ┆ 0.949219  ┆ … ┆ lip_balm  ┆ household ┆ 824       ┆ 4         │
# │           ┆          ┆ n         ┆           ┆   ┆           ┆ _items_an ┆           ┆           │
# │           ┆          ┆           ┆           ┆   ┆           ┆ d_furnitu ┆           ┆           │
# ...

# %%
assert len(df) == len(ds)
