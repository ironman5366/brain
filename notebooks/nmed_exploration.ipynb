# %%
import scipy.io
from pathlib import Path

NMED_PATH = Path(
    "/kreka/research/willy/side/brain_datasets/nmed"
)

# %%
mat_path = NMED_PATH / "05_2_raw.mat"

# %%
import h5py

f = h5py.File(
    mat_path, 'r'
)
