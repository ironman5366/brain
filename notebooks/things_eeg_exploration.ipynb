# %%
from pathlib import Path

# %%
base = Path("/kreka/research/willy/side/brain_datasets/EEG_Image_decode")

# %%
sub_01 = base / "Preprocessed_data_250Hz/sub-01"

# %%
preprocessed_test = sub_01 / "preprocessed_eeg_test.npy"

# %%
import numpy as np

# %%
d = np.load(preprocessed_test, allow_pickle=True)

# %%
type(d)
# Out:
# dict

# %%
d.keys()
# Out:
# dict_keys(['preprocessed_eeg_data', 'ch_names', 'times'])

# %%
d['preprocessed_eeg_data'].shape
# Out:
# (200, 80, 63, 250)
